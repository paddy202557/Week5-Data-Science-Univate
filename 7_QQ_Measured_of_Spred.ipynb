# %%
from QQUnivariate import QQUnivariate
import pandas as pd
import numpy as np

# %% [markdown]
# # Variance  &  Standard Deviation

# %%
# Mean - Average value (Center of the data) Mean = X
# Variance (Squared) help us to understand  the variance is how for from Mean.   
# Population Variance(all data in the data set): Averaging the Variance (Squared value) 
#                                 = Data point value  - Mean value / Number of Data Points
# Sample Varaince (Sample data in  the data set): Averaging the Variance (Squared value) 
#                                = Data point value  - Mean value / Number of Data Points - 1

# %%
# Standard Deviation (Not Squared) help us to Understand the  spread of the data 
#      standard deviation is often preferred because it is expressed in the same units as the original data

# %%
dataset=pd.read_csv("Placement.csv")

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %% [markdown]
# # Split the data columns to  Qunatitative  & Qulitative by calling a function

# %%
#Call the  function to  split the columns  by  data type
QQUnivariate.quanQual(dataset)
# Out:
# (['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary'],
#  ['gender',
#   'ssc_b',
#   'hsc_b',
#   'hsc_s',
#   'degree_t',
#   'workex',
#   'specialisation',
#   'status'])

# %%
Quan,Qual =QQUnivariate.quanQual(dataset)

# %%
Quan
# Out:
# ['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']

# %% [markdown]
# # Measure of Spread

# %%
dataset["ssc_p"].var()
# Out:
# 117.2283767354923

# %%
dataset["ssc_p"].std()
# Out:
# 10.827205398231452

# %%
#Callthe function to calculate the unvariate column values
descriptive=QQUnivariate.Univariate(Quan,dataset)

# %%
descriptive
# Out:
#             sl_no     ssc_p     hsc_p   degree_p   etest_p     mba_p  \
# Mean          108        67        66         66        72        62
# Median        108        67        65         66        71        62
# Mode            1        62        63         65        60      56.7
# Q1:25%       54.5      60.6      60.9         61        60    57.945
# Q2:50%        108        67        65         66        71        62
# Q3:75%      161.5      75.7        73         72      83.5    66.255
# Q4:100%       215      89.4      97.7         91        98     77.89
# 99%        212.86        87     91.86      83.86        97   76.1142
# IQR           107      15.1      12.1         11      23.5      8.31
# 1.5rule     160.5     22.65     18.15       16.5     35.25    12.465
# Lesser       -106     37.95     42.75       44.5     24.75     45.48
# Greater       322     98.35     91.15       88.5    118.75     78.72
# Min             1     40.89        37         50        50     51.21
# ...
